# %%
import pandas as pd 
import numpy as np
from scipy.sparse import coo_matrix

# %%
from lightfm import LightFM
from lightfm.evaluation import auc_score

import time

# %%
# import data

# %%
# merge the data 
full_table = pd.merge() #for drivers
fill_table = pd.merge() #for passengers

#affihce les resultats
